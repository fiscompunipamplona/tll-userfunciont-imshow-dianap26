# %%
from google.colab import drive
from os.path import join

# %%
ROOT = '/content/drive'
PROJ = 'My Drive/1clone'

GIT_USERNAME = "dianap26"
GIT_TOKEN = "9578af0ab9798ba992fdad3bccd8d4bf6fed36e1"
GIT_REPOSITORY = "fiscompunipamplona/tll-userfunciont-imshow-dianap26"
GIT_PATH = "https://9578af0ab9798ba992fdad3bccd8d4bf6fed36e1@github.com/fiscompunipamplona/tll-userfunciont-imshow-dianap26.git"

drive.mount(ROOT)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
PROJECT_PATH = join(ROOT, PROJ)
# !mkdir "{PROJECT_PATH}"
# Out:
# mkdir: cannot create directory ‘/content/drive/My Drive/1clone’: File exists

# %%
PROJECT_PATH = join(ROOT, PROJ)

# !git clone "{GIT_PATH}"
# !rsync -ap tll-userfunciont-imshow-dianap26 "{PROJECT_PATH}"
# Out:
# Cloning into 'tll-userfunciont-imshow-dianap26'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3 (delta 0), reused 3 (delta 0), pack-reused 0
# Unpacking objects: 100% (3/3), done.

# %%
# %cd "{PROJECT_PATH}"/tll-userfunciont-imshow-dianap26/

# !ls

# !git config --global user.email "dianabv2687@gmail.com"
# !git config --global user.name "dianap26"

# !git remote rm origin

# !git config --global github.user "{GIT_USERNAME}"
# !git config --global github.token "{GIT_TOKEN}"

# !git add *
# !git commit -m "nuevo noobook agregado"

# !git remote add origin https://"{GIT_TOKEN}"@github.com/"{GIT_REPOSITORY}".git

# !git push -u origin master
